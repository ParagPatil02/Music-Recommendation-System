# %% [markdown]
# # LetsGrowMore (LGMVIP) - "DATA SCIENCE INTERN"

# %% [markdown]
# # LGMVIP APRIL-22

# %% [markdown]
# # AUTHOR - PARAG PATIL

# %% [markdown]
# ## BEGINNER LEVEL TASK

# %% [markdown]
# ### TASK-3- Music Recommendation System: Music recommender systems can suggest songs to users based on their listening patterns

# %% [markdown]
# ### Dataset link : https://www.kaggle.com/c/kkbox-music-recommendation-challenge/data

# %% [markdown]
# # Importing Libraries

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing datasets

# %%
#IMPORTING DATASETS
ntr = 7000
nts = 3000
data_path = r"D:\letsgrowmore projects\task  no 4 music\train.csv"
train = pd.read_csv(data_path,nrows=ntr)
names=['msno','song_id','source_system_tab','source_screen_name','source_type','target']
test1 = pd.read_csv(data_path,names=names,skiprows=ntr,nrows=nts)
songs = pd.read_csv(r"D:\letsgrowmore projects\task  no 4 music\songs.csv")
members = pd.read_csv(r"D:\letsgrowmore projects\task  no 4 music\members.csv")

# %%
train.head(10)
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 7  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 8  uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 9  uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
# 5  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=           explore
# 6  VkILU0H1h3NMmk9MQrXouNudGk5n8Ls5cqRRuBxeTh4=        my library
# 7  bPIvRTzfHxH5LgHrStll+tYwSQNVV8PySgA3M1PfTgc=           explore
# 8  /bU6IRSK+YNlNbaTkxo7bhsb2EDLPrnksdX3ggcZNhI=        my library
# 9  EbI7xoNxI+3QSsiHxL13zBdgHIJOwa3srHd7cDcnJ0g=        my library
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# 4              Explore  online-playlist       1
# 5              Explore  online-playlist       1
# 6  Local playlist more   local-playlist       1
# 7              Explore  online-playlist       1
# 8  Local playlist more    local-library       1
# 9  Local playlist more    local-library       1

# %%
train.sample(10)
# Out:
#                                               msno  \
# 506   Dqh0zoxytLLbFt/7Q3QJ6Zb2g00D3PNh84PEWYENd2o=
# 3084  vf72WjMnAjr9ELP36xOjbCXhXQTk2qCQ1MW56xKT12s=
# 866   zY1X90IOjnfHCDVA4pb3Ih2euO9H1cPb8OJkOBppoSg=
# 3344  LGIeu7rj6KryPWev2nr5g807ZPtw4b59wqDn5jighcw=
# 3924  eSEKewUNs67gdwQSm721KUW8kNgMARhMbknE26jiT7c=
# 54    0LhkakIQDn36HZXI6ClQSO7W7jkpZAy+9MvYgPOZGrA=
# 4162  eU8WVZclSIjgIiuu7uYL3f7pwdw+XmOUjRSE7KlAZv0=
# 6106  s6YYVO8Ux3UBpjTwLCWNwwifpOacsOhYMNv/y4DtCO8=
# 603   +6qXndZ2nMn0cyAWZlBfOBGVqolfO2CRo1MdVznK7Kg=
# 3750  IPctNXFZDMiWinj7Ag0GJTbIP9owKd5WaZ0tFb/STAs=
#
#                                            song_id source_system_tab  \
# 506   WDhQhhbq+bwhBY642Fx3e5eGBdvqzzXmwiouCaVI0R0=          discover
# 3084  QNxqv7nOTkK8o0jbfEcXCUzEg8SPfgiesqL4Gyg5K1Y=        my library
# 866   Of/tj0IkPDmWYdWLmcmtMH7+rAwHRBIlJb1xnVbY9Ms=        my library
# 3344  wR+LLM957WfBdaXmUsdE9AiGzOVki7yjelGea+0Ze8E=          discover
# 3924  9tNXaK/yKJfTcoWLRFw6HXplizDxq4bFvzs3scmesCU=        my library
# 54    PgRtmmESVNtWjoZHO5a1r21vIz9sVZmcJJpFCbRa1LI=        my library
# 4162  HzCFc9gU/AuYNF1ld1ZlyeCpQvVLTonc8+ZrUAidmmY=          discover
# 6106  RGkmslTJL2ttLJXD2iMSiX3SbfIQr/IVtxdLn2dx/zo=        my library
# 603   r0L/P3z905IMYFiwrfhCWEi82VUCTONy0TLuu/Zg2qw=          discover
# 3750  X8uGX+w3qTMTG8S5wauveoBnE81OP99ywklEVcXRHYE=        my library
#
#         source_screen_name          source_type  target
# 506   Online playlist more      online-playlist       1
# 3084   Local playlist more       local-playlist       1
# 866    Local playlist more       local-playlist       1
# 3344  Online playlist more  song-based-playlist       0
# 3924   Local playlist more       local-playlist       1
# 54     Local playlist more       local-playlist       1
# 4162      Discover Feature  song-based-playlist       1
# 6106   Local playlist more        local-library       1
# 603                Unknown      online-playlist       0
# 3750   Local playlist more       local-playlist       1

# %%
train.shape
# Out:
# (7000, 6)

# %%
train.columns
# Out:
# Index(['msno', 'song_id', 'source_system_tab', 'source_screen_name',
#        'source_type', 'target'],
#       dtype='object')

# %%
train.describe()
# Out:
#             target
# count  7000.000000
# mean      0.783429
# std       0.411937
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   msno                7000 non-null   object
#  1   song_id             7000 non-null   object
#  2   source_system_tab   6986 non-null   object
#  3   source_screen_name  6815 non-null   object
#  4   source_type         6986 non-null   object
#  5   target              7000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 328.2+ KB

# %%
train.isnull().sum()
# Out:
# msno                    0
# song_id                 0
# source_system_tab      14
# source_screen_name    185
# source_type            14
# target                  0
# dtype: int64

# %% [markdown]
# # Songs datasets

# %%
songs.head(10)
# Out:
#                                         song_id  song_length        genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640              465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328              444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781              465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554              465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329              726
# 5  kKJ2JNU5h8rphyW21ovC+RZU+yEHPM+3w85J37p7vEQ=       235520  864|857|850|843
# 6  N9vbanw7BSMoUgdfJlgX1aZPE1XZg8OS1wf88AQEcMc=       226220              458
# 7  GsCpr618xfveHYJdo+E5SybrpR906tsjLMeKyrCNw8s=       276793              465
# 8  oTi7oINPX+rxoGp+3O6llSltQTl80jDqHoULfRoLcG4=       228623              465
# 9  btcG03OHY3GNKWccPP0auvtSbhxog/kllIIOx5grE/k=       232629         352|1995
#
#          artist_name                                           composer  \
# 0   張信哲 (Jeff Chang)                                                 董貞
# 1          BLACKPINK                 TEDDY|  FUTURE BOUNCE|  Bekuh BOOM
# 2       SUPER JUNIOR                                                NaN
# 3              S.H.E                                                湯小康
# 4               貴族精選                                        Traditional
# 5               貴族精選                                       Joe Hisaishi
# 6    伍佰 & China Blue                                       Jonathan Lee
# 7  光良 (Michael Wong)                                                 光良
# 8       林俊傑 (JJ Lin)                                             JJ Lin
# 9           Kodaline  Stephen Garrigan| Mark Prendergast| Vincent Ma...
#
#                                             lyricist  language
# 0                                                何啟弘       3.0
# 1                                              TEDDY      31.0
# 2                                                NaN      31.0
# 3                                                徐世珍       3.0
# 4                                        Traditional      52.0
# 5                                     Hayao Miyazaki      17.0
# 6                                                NaN       3.0
# 7                                                彭資閔       3.0
# 8                                       Wu Qing Feng       3.0
# 9  Stephen Garrigan| Mark Prendergast| Vincent Ma...      52.0

# %%
songs.sample(10)
# Out:
#                                               song_id  song_length genre_ids  \
# 1598511  fyTfjJx4kPBp7RpCpPBKuQUWP3Vl25azbg8xj5oY3Cg=       303020       786
# 609202   +iU7z4KVPjGQQ7ELquAWAgFANXz5PnFdD70awhzvQ0w=       165976       465
# 1739656  A1W9ECWMzYkx/z+HeRa+qIiJSShRyrCgXzELe/2mgto=       108878       958
# 1315795  k8dfxWLtNu0WrOpjZssXGYKD4fvOtWm9eEzpSpiBGSM=       205752       465
# 2217176  TUpNw5o707pPO5Rb+PoPn9C/HIoGe5vkPopN0qTdV/Q=       177586       958
# 2026417  ZRoQskPPIjhZq0ddqTcifN606GAar2dsJNIjxaOLibk=       311066  2213|465
# 1047784  O/+q9FvL8W8C/iR1hXtqyisYXmpzU6AgJpf1SL52sdA=       234083      1259
# 967944   OFCKZnfJBJy424uE5XgxNGU7pMk37tMrmK4zQCKJ4Vc=       131526      1011
# 645801   7ehwwallTC//kH7fRvPewfI2WpNBOFEawp8paupBDVE=       120058       NaN
# 257425   Yw4Yp4yI9qom72ci9frFBVm7iGWsoke3uuA2iGQ0cUc=       252865       958
#
#                    artist_name                composer     lyricist  language
# 1598511                    朱可可                     NaN          NaN      -1.0
# 609202             Dean Martin  Leo Corday| Al Hoffman          NaN      52.0
# 1739656       Benjamin Verdery                  Prince          NaN      -1.0
# 1315795        彭羚 (Cass Phang)                     NaN          NaN      24.0
# 2217176         Andrea Bocelli                     NaN          NaN      -1.0
# 2026417      อั๋น Feeble Heart                     NaN          NaN      45.0
# 1047784          Missy Elliott                     NaN          NaN      52.0
# 967944          Lonnie Donegan             Traditional  Traditional      52.0
# 645801   Soft Background Music                     NaN          NaN      -1.0
# 257425         Antonio Vivaldi                     NaN          NaN      -1.0

# %%
songs.shape
# Out:
# (2296320, 7)

# %%
songs.columns
# Out:
# Index(['song_id', 'song_length', 'genre_ids', 'artist_name', 'composer',
#        'lyricist', 'language'],
#       dtype='object')

# %%
songs.describe()
# Out:
#         song_length      language
# count  2.296320e+06  2.296319e+06
# mean   2.469935e+05  3.237800e+01
# std    1.609200e+05  2.433241e+01
# min    1.850000e+02 -1.000000e+00
# 25%    1.836000e+05 -1.000000e+00
# 50%    2.266270e+05  5.200000e+01
# 75%    2.772690e+05  5.200000e+01
# max    1.217385e+07  5.900000e+01

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2296320 entries, 0 to 2296319
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   song_id      object
#  1   song_length  int64
#  2   genre_ids    object
#  3   artist_name  object
#  4   composer     object
#  5   lyricist     object
#  6   language     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 122.6+ MB

# %%
songs.isnull().sum()
# Out:
# song_id              0
# song_length          0
# genre_ids        94116
# artist_name          0
# composer       1071354
# lyricist       1945268
# language             1
# dtype: int64

# %% [markdown]
# # Members datasets

# %%
members.head(10)
# Out:
#                                            msno  city  bd  gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0     NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0     NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0     NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0     NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0     NaN
# 5  zgPOEyUn5a/Fvuzb3m69ajzxjkbblVtObglW89FzLdo=    13  43  female
# 6  Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=     1   0     NaN
# 7  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY=     1   0     NaN
# 8  kfk1AdTNH2dNqF5LzIs4e0vwGPejw2jrnFjJlcYnEgk=     1   0     NaN
# 9  tscijwx4dbEp0NXGl+iFtHJ8zrj+TkcMrduOQk9t+gE=     1   0     NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20110820         20170920
# 1               7                20150628         20170622
# 2               4                20160411         20170712
# 3               9                20150906         20150907
# 4               4                20170126         20170613
# 5               9                20120703         20171006
# 6               4                20160326         20160329
# 7               7                20160130         20170930
# 8               7                20110111         20170930
# 9               7                20160217         20170613

# %%
members.sample(10)
# Out:
#                                                msno  city  bd  gender  \
# 8169   7uzBo6JcNRuJxO7jq9TBXadnN+TjLw+meX6Hs51KIes=    15  21  female
# 1496   WJPSkwnnJPvAtlTu1bQZMKvjr4ScCrN3JHWivAvxDrM=    13  38  female
# 10895  FXitlEwv6zumiYxlXfgkeqX5n/gUFqyjhkC7rgMg6B4=     1   0     NaN
# 23982  udrjEiiz+/0gXTONL1SeVkU7ZB53YbqfGm0tNrFRwaw=    15  21    male
# 27769  DVwd5/NUTsZo7iSXKfD8BkROurunK5m5wnMzZ9gkNzY=    14  20  female
# 17067  t29f4R7fZgX8fa2QavbgNim25mLBPlP0Cmh7Ahh/DVs=     1   0     NaN
# 21741  BOB0Tf7fxYoZqOPuAdgmi90AOt0E2gI+JNlXXL9uw+0=     1   0     NaN
# 20882  QDCZuBNbpbxpOkKDp3ZTowJGe1f+ioxPRH+UVUphPfk=     1   0     NaN
# 17585  w9Vz+3++rxR6KCcxJtcuz/xTq8u2SC093LxvZK6WeoA=    12  19    male
# 9536   Sd3Ltyd45hb9Qzx3Yx7q7kwBmfM5bZksxR7iH0IyGu8=     9  20  female
#
#        registered_via  registration_init_time  expiration_date
# 8169                3                20170201         20180220
# 1496                9                20100124         20170929
# 10895               4                20151122         20170108
# 23982               9                20070506         20171007
# 27769               9                20140912         20160728
# 17067               9                20150404         20170417
# 21741               7                20140717         20170915
# 20882               4                20170126         20170129
# 17585               4                20160313         20180413
# 9536                4                20151216         20170709

# %%
members.shape
# Out:
# (34403, 7)

# %%
members.columns
# Out:
# Index(['msno', 'city', 'bd', 'gender', 'registered_via',
#        'registration_init_time', 'expiration_date'],
#       dtype='object')

# %%
members.describe()
# Out:
#                city            bd  registered_via  registration_init_time  \
# count  34403.000000  34403.000000    34403.000000            3.440300e+04
# mean       5.371276     12.280935        5.953376            2.013994e+07
# std        6.243929     18.170251        2.287534            2.954015e+04
# min        1.000000    -43.000000        3.000000            2.004033e+07
# 25%        1.000000      0.000000        4.000000            2.012103e+07
# 50%        1.000000      0.000000        7.000000            2.015090e+07
# 75%       10.000000     25.000000        9.000000            2.016110e+07
# max       22.000000   1051.000000       16.000000            2.017023e+07
#
#        expiration_date
# count     3.440300e+04
# mean      2.016901e+07
# std       7.320925e+03
# min       1.970010e+07
# 25%       2.017020e+07
# 50%       2.017091e+07
# 75%       2.017093e+07
# max       2.020102e+07

# %%
members.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34403 entries, 0 to 34402
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   msno                    34403 non-null  object
#  1   city                    34403 non-null  int64
#  2   bd                      34403 non-null  int64
#  3   gender                  14501 non-null  object
#  4   registered_via          34403 non-null  int64
#  5   registration_init_time  34403 non-null  int64
#  6   expiration_date         34403 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 1.8+ MB

# %%
members.isnull().sum()
# Out:
# msno                          0
# city                          0
# bd                            0
# gender                    19902
# registered_via                0
# registration_init_time        0
# expiration_date               0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
#DATA VISUALIZATION
plt.figure(figsize=(12,6))
sns.countplot(x = train['source_system_tab'],hue=train['source_system_tab'])
# Out:
# <AxesSubplot:xlabel='source_system_tab', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x = train['source_screen_name'],palette=['magenta','blue'],hue=train['target'],data = train,orient='v')
plt.xticks(rotation =90)
plt.show()

# %%
plt.figure(figsize=(15,9))
sns.set(font_scale=2)
sns.countplot(x='source_type',hue='source_type',data=train,edgecolor=sns.color_palette('magma',5))
sns.set(style="ticks")
plt.xlabel('source types',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.xticks(rotation='60')
plt.title('Count plot source types for listening music',fontsize=20)
plt.tight_layout()

# %% [markdown]
# 1.source_system_tab indicates the name of the tab where the event was triggered. System tabs are used to categorize KKBOX mobile apps functions.
#
# 2.It can be depicted from the above plot that people repeat songs from their library or discover tabs.
#
# 3.From notifications or settings tab people are not interested to repeat songs.

# %%
plt.figure(figsize=(10,8))
sns.set(font_scale=2)
sns.countplot(y='source_screen_name',data=train,facecolor=(0,0,0,0),linewidth=2,edgecolor=sns.color_palette('magma',5))
sns.set(style="darkgrid")
plt.xlabel('source types',fontsize=15)
plt.ylabel('count',fontsize=15)
plt.xticks(rotation='60')
plt.title('Count plot for which  screen using ',fontsize=15)
plt.tight_layout()

# %%
def count_plot(data, x, hue, type):
  plt.figure(figsize = (15, 8))
  sns.set(font_scale = 2)
  sns.countplot(x = x, hue = hue, data = data)
  plt.xlabel(x, fontsize = 30)
  plt.ylabel('count', fontsize = 30)
  plt.xticks(rotation = '90')
  plt.title('Count plot for {0} in {1} data'.format(x, type), fontsize = 30)
  plt.tight_layout()

# %%
# Function to plot histograms for categories

def count_plot_function(data, x):
  plt.figure(figsize = (15,10))
  sns.set(font_scale = 2)
  sns.countplot(x = x, data = data)
  plt.xlabel(x, fontsize = 30)
  plt.ylabel('count', fontsize = 30)
  plt.xticks(rotation = '90')
  plt.title('Count plot', fontsize = 30)
  plt.tight_layout()

# %%
sns.countplot(x = train['source_type'],palette=['coral','cyan'],hue=train['target'],data = train,orient='v')
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# # Now doing some visualiaztion in members.csv

# %%
import matplotlib as mpl

mpl.rcParams['font.size'] = 40.0
labels = ['Male','Female']
colors = ['#66b3ff','#ff9999']
plt.figure(figsize = (8, 8))
sizes = pd.value_counts(members.gender)
patches, texts, autotexts = plt.pie(sizes, 
                                    labels=labels,colors=colors, autopct='%.0f%%',
                                    shadow=True, radius=1,startangle=90)
for t in texts:
    t.set_size('smaller')
plt.legend()
plt.show()

# %%
sns.countplot(x = songs['language'],data =train,hue=songs['language'],orient='v')
# Out:
# <AxesSubplot:xlabel='language', ylabel='count'>

# %%
count_plot_function(members, 'registered_via')

# %% [markdown]
# Most of the registrations happened via method '4', '7' and '9'.
#
# Few uses have registered theirselves via '13' and '16' methods.

# %%
count_plot_function(members, 'city')

# %% [markdown]
# Most of the people who used to listen songs are from '1'- labelled city.
#
# Some cities have very few people who prefer listening music via this music app

# %% [markdown]
# # Doing stats test on members.csv

# %%
plt.figure(figsize = (18, 18)) 
sns.distplot(members.registration_init_time,color='orange')
sns.set(font_scale=2)
plt.ylabel('Density',fontsize=50)
plt.xlabel('registration time ' ,fontsize=50)
plt.title('PDF for Registration')
# Out:
# Text(0.5, 1.0, 'PDF for Registration')

# %% [markdown]
# We can see that initially people were not fond of listening music but after certain amount time people started to listen music and registered themselves to this music app

# %%
# Function to plot PDF and CDf.

def plot_pdf_cdf(x, flag):
  plt.figure(figsize = (10, 6)) 
  kwargs = {'cumulative': True}
  if flag:
    sns.distplot(x, hist_kws = kwargs, kde_kws = kwargs,color='purple')
    plt.title('CDF for age')
  else:
    sns.distplot(x,color='purple')
    plt.title('PDF for age')
  sns.set(font_scale=2)

# %%
plot_pdf_cdf(members['bd'], False)

# %%
plot_pdf_cdf(members['bd'], True)
plt.show()

# %%
np.percentile(members['bd'].values, 98)
# Out:
# 47.0

# %% [markdown]
# 1.98th percentile user is of 47 age.
#
# 2.Means most of the user are below 50.
#
# 3.We can also observe via above CDF that almost 99% values are below 50. There are also some outliers like 1030, -38, -43, 1051, etc. As age cannot be negative value or more than 1000 for humans

# %%
#DATA PREPROCESSING AND CLEANING
test = test1.drop(['target'],axis=1)
ytr = np.array(test1['target'])

# %%
test_name = ['id','msno','song_id','source_system_tab',\
             'source_screen_name','source_type']
test['id']=np.arange(nts)
test = test[test_name]

# %%
song_cols = ['song_id', 'artist_name', 'genre_ids', 'song_length', 'language']
train = train.merge(songs[song_cols], on='song_id', how='left')
test = test.merge(songs[song_cols], on='song_id', how='left')

# %%
members['registration_year'] = members['registration_init_time'].apply(lambda x: int(str(x)[0:4]))
members['registration_month'] = members['registration_init_time'].apply(lambda x: int(str(x)[4:6]))
members['registration_date'] = members['registration_init_time'].apply(lambda x: int(str(x)[6:8]))

# %%
members['expiration_year'] = members['expiration_date'].apply(lambda x: int(str(x)[0:4]))
members['expiration_month'] = members['expiration_date'].apply(lambda x: int(str(x)[4:6]))
members['expiration_date'] = members['expiration_date'].apply(lambda x: int(str(x)[6:8]))
members = members.drop(['registration_init_time'], axis=1)

# %%
members_cols = members.columns
train = train.merge(members[members_cols], on='msno', how='left')
test = test.merge(members[members_cols], on='msno', how='left')

# %%
train = train.fillna(-1)
test = test.fillna(-1)

# %%
import gc
del members, songs; gc.collect();

# %%
colm = list(train.columns)
colm.remove('target')

# %%
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
for col in tqdm(colm):
    if train[col].dtype == 'object':
        train[col] = train[col].apply(str)
        test[col] = test[col].apply(str)

        le = LabelEncoder()
        train_vals = list(train[col].unique())
        test_vals = list(test[col].unique())
        le.fit(train_vals + test_vals)
        train[col] = le.transform(train[col])
        test[col] = le.transform(test[col])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 135.69it/s]

# %%
unique_songs = range(max(train['song_id'].max(), test['song_id'].max()))
song_popularity = pd.DataFrame({'song_id': unique_songs, 'popularity':0})

train_sorted = train.sort_values('song_id')
train_sorted.reset_index(drop=True, inplace=True)
test_sorted = test.sort_values('song_id')
test_sorted.reset_index(drop=True, inplace=True)

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 921.5 kB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\sbpat\appdata\local\programs\python\python310\lib\site-packages (from lightgbm) (1.22.0)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\sbpat\appdata\local\programs\python\python310\lib\site-packages (from lightgbm) (1.0.2)
# Requirement already satisfied: scipy in c:\users\sbpat\appdata\local\programs\python\python310\lib\site-packages (from lightgbm) (1.7.3)
# Requirement already satisfied: wheel in c:\users\sbpat\appdata\local\programs\python\python310\lib\site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sbpat\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\sbpat\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Model Building

# %%
#MODEL BUILDING
from sklearn.model_selection import train_test_split
import lightgbm as lgb
X = np.array(train.drop(['target'], axis=1))
y = train['target'].values

X_test = np.array(test.drop(['id'], axis=1))
ids = test['id'].values

del train, test; gc.collect();

X_train, X_valid, y_train, y_valid = train_test_split(X, y, \
    test_size=0.1, random_state = 12)
    
del X, y; gc.collect();

d_train = lgb.Dataset(X_train, label=y_train)
d_valid = lgb.Dataset(X_valid, label=y_valid) 

watchlist = [d_train, d_valid]

# %% [markdown]
# # Trying out basic classification models

# %%
#TRYING OUT BASIC CLASSIFICATION MODELS
def predict(m1_model):
    model = m1_model.fit(X_train,y_train)
    print('Training Score : {}'.format(model.score(X_train,y_train)))
    y_pred = model.predict(X_valid)
    #accuracy_score = m1_model.metrics.accuracy_score(y_valid,y_pred)
    #print('Accuracy Score : {}'.format(accuracy_score))
    v_test = model.predict(X_test)
    yhat = (v_test>0.5).astype(int)
    comp = (yhat==ytr).astype(int)
    acc = comp.sum()/comp.size*100
    print("Accuracy on test data for the model", acc)

# %% [markdown]
# # Predicting training score & accuracy on test data using

# %% [markdown]
# # LogisticRegression & RandomForestClassifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
predict(LogisticRegression())
# Out:
# Training Score : 0.783968253968254
# Accuracy on test data for the model 74.9

# %%
predict(RandomForestClassifier())
# Out:
# Training Score : 1.0
# Accuracy on test data for the model 79.13333333333334

# %% [markdown]
# # Prediction using lightgbm

# %%
#PREDICTION USING LIGHTGBM
params = {}
params['learning_rate'] = 0.4
params['application'] = 'binary'
params['max_depth'] = 15
params['num_leaves'] = 2**8
params['verbosity'] = 0
params['metric'] = 'auc'

model1 = lgb.train(params, train_set=d_train, num_boost_round=200, valid_sets=watchlist, \
early_stopping_rounds=10, verbose_eval=10)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001101 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	training's auc: 0.993218	valid_1's auc: 0.843149
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	training's auc: 0.999945	valid_1's auc: 0.834637
# Early stopping, best iteration is:
# [10]	training's auc: 0.993218	valid_1's auc: 0.843149

# %%
p_test = model1.predict(X_test)

# %% [markdown]
# # Printing accuracy of lgbm model on test data

# %%
yhat = (p_test>0.5).astype(int)
comp = (yhat==ytr).astype(int)
acc = comp.sum()/comp.size*100
print('The accuracy of lgbm model on test data is: {0:f}%'.format(acc))
# Out:
# The accuracy of lgbm model on test data is: 78.566667%
